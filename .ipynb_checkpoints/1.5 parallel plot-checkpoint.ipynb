# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
sampleXdf = pd.read_pickle("data/SampleX.pkl")
fig = plt.figure()
fig.set_figheight(10)
fig.set_figwidth(20)
plt.plot(sampleXdf)
plt.grid()
plt.show()
