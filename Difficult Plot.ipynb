# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
AV = [0, 20, 0, 0, 0, 0]
IV = [30, 45, 60, 40, 40, 40]
DO = [15, 20, 25, 15, 20, 25]
N = 240
V = 441
x1 = 21
x2 = 21
L = 6
nsrcs = 6

# %%
SMcmap = sns.cubehelix_palette(start=.5, rot=-.75, as_cmap=True)
TCcmap = sns.cubehelix_palette(start=.5, rot=-.5, as_cmap=True)
TCcolor = "darkturquoise"

# %%
sampleXdf = pd.read_pickle("SampleX.pkl")
fig = plt.figure()
fig.set_figheight(10)
fig.set_figwidth(20)
plt.plot(sampleXdf)
plt.grid()
plt.show()

# %%
ARR = pd.read_pickle("ARR.pkl").to_numpy()
DRR = pd.read_pickle("DRR.pkl").to_numpy()
ALR = pd.read_pickle("ALR.pkl").to_numpy()
DLR = pd.read_pickle("DLR.pkl").to_numpy()

# %%
# plot the retrieved data set D and A using RR and LR
fig, axes = plt.subplots(6, 4) 
fig.set_figheight(30)
fig.set_figwidth(20)


for i in range(nsrcs):
    axes[i][0].set_title("RR Retrieved Spatial Maps")
    sns.heatmap(ARR[i].reshape(x1,x2), cmap=SMcmap, ax = axes[i,0])
    axes[i][1].set_title("RR Retrieved Time Courses")
    axes[i][1].plot(x, DRR[:, i], color = TCcolor)

for i in range(nsrcs):
    axes[i][2].set_title("LR Retrieved Spatial Maps")
    sns.heatmap(ALR[i].reshape(x1,x2), cmap=SMcmap, ax = axes[i,])
    axes[i][3].set_title("LR Retrieved Time Courses")
    axes[i][3].plot(x, DLR[:, i], color = TCcolor)
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_449747/2807246347.py in <module>
#       7 for i in range(nsrcs):
#       8     axes[i][0].set_title("RR Retrieved Spatial Maps")
# ----> 9     sns.heatmap(ARR[i].reshape(x1,x2), cmap=SMcmap, ax = axes[i,0])
#      10     axes[i][1].set_title("RR Retrieved Time Courses")
#      11     axes[i][1].plot(x, DRR[:, i], color = TCcolor)
#
# NameError: name 'SMcmap' is not defined
